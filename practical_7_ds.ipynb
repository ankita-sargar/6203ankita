# %% [markdown]
# <a href="https://colab.research.google.com/github/ankita-sargar/6203ankita/blob/main/practical_7_ds.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_excel("/content/wc2023.xlsx")
data
# Out:
#      team                     player bat_or_bowl  bb_bf  runs  wkts  \
# 0     PAK  Shaheen Shah Afridi (PAK)        bowl     60    45   3.0
# 1     ENG            DJ Willey (ENG)        bowl     60    45   3.0
# 2      NZ              MJ Henry (NZ)        bowl     60    48   3.0
# 3      NZ           LH Ferguson (NZ)        bowl     60    49   3.0
# 4     AFG           Noor Ahmad (AFG)        bowl     60    49   3.0
# ...   ...                        ...         ...    ...   ...   ...
# 1432  IND       Mohammed Shami (IND)        bowl     42    47   1.0
# 1433  AUS              TM Head (AUS)        bowl     12     4   0.0
# 1434  AUS             MR Marsh (AUS)        bowl     12     5   0.0
# 1435  IND            RA Jadeja (IND)        bowl     60    43   0.0
# 1436  IND        Kuldeep Yadav (IND)        bowl     60    56   0.0
#
#       wicketball_prob  runs_per_ball      opposition     ground start_date  \
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread("/content/panda.jpg")
plt.imshow(img)

# %% [markdown]
# Summarizing Data With statistic

# %%
import pandas as pd
df=pd.DataFrame({"serial_no":[1,2,3,4,5],"roll_no":[21,22,23,24,25],
                 "Name":["manasi","pratiksha","ankita",'chimaya',"sonali"],
                 "class":["A","B","A","A","B"],
                 "marks":[10,80,80,73,55]})
df
# Out:
#    serial_no  roll_no       Name class  marks
# 0          1       21     manasi     A     10
# 1          2       22  pratiksha     B     80
# 2          3       23     ankita     A     80
# 3          4       24    chimaya     A     73
# 4          5       25     sonali     B     55

# %%
df.isnull().sum()
# Out:
# serial_no    0
# roll_no      0
# Name         0
# class        0
# marks        0
# dtype: int64

# %%
df.describe()
# Out:
#        serial_no    roll_no     marks
# count   5.000000   5.000000   5.00000
# mean    3.000000  23.000000  59.60000
# std     1.581139   1.581139  29.55165
# min     1.000000  21.000000  10.00000
# 25%     2.000000  22.000000  55.00000
# 50%     3.000000  23.000000  73.00000
# 75%     4.000000  24.000000  80.00000
# max     5.000000  25.000000  80.00000

# %%
df.value_counts()
# Out:
# serial_no  roll_no  Name       class  marks
# 1          21       manasi     A      10       1
# 2          22       pratiksha  B      80       1
# 3          23       ankita     A      80       1
# 4          24       chimaya    A      73       1
# 5          25       sonali     B      55       1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   serial_no  5 non-null      int64
#  1   roll_no    5 non-null      int64
#  2   Name       5 non-null      object
#  3   class      5 non-null      object
#  4   marks      5 non-null      int64
# dtypes: int64(3), object(2)
# memory usage: 328.0+ bytes

# %%
df.describe(include="object")
# Out:
#           Name class
# count        5     5
# unique       5     2
# top     manasi     A
# freq         1     3

# %%
df.nunique()
# Out:
# serial_no    5
# roll_no      5
# Name         5
# class        2
# marks        4
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.duplicated(['Name']).sum()
# Out:
# 0

# %%
df['Name'].value_counts()
# Out:
# manasi       1
# pratiksha    1
# ankita       1
# chimaya      1
# sonali       1
# Name: Name, dtype: int64

# %%
df['class'].value_counts()
# Out:
# A    3
# B    2
# Name: class, dtype: int64

# %%
df['class'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0    A
# 1    B
# 2    A
# 3    A
# 4    B
# Name: class, dtype: object>

# %%
df['marks'].mean()
# Out:
# 59.6

# %%
df.var()
# Out:
# <ipython-input-27-28ded241fd7c>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# serial_no      2.5
# roll_no        2.5
# marks        873.3
# dtype: float64

# %%
correlation=df.corr()
correlation
# Out:
# <ipython-input-28-edac34d0c35e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation=df.corr()
#            serial_no   roll_no     marks
# serial_no   1.000000  1.000000  0.444085
# roll_no     1.000000  1.000000  0.444085
# marks       0.444085  0.444085  1.000000

# %%
import seaborn as sns
sns.heatmap(correlation,annot=True,fmt='.2f',cmap='plasma')
# Out:
# <Axes: >
